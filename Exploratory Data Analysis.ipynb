# %% [markdown]
# <p>The Data used for below analysis has been provided by <a href="https://www.worldbank.org">The World Bank</a>. </p>
# <p>Exploring and analyzing international debt data collected by The World Bank. The dataset contains information about the amount of debt (in USD) owed by developing countries across several categories (debt indicators) w.r.t the year <b>2020</b>.

# %%
#pip install sql
#pip install ipython-sql
#pip install prettytable==2.5.0

# %%
# %load_ext sql

# %%
from sqlalchemy import create_engine

# %%
# %sql postgresql://postgres:Tata%40890@localhost/ids_database

# %% [raw]
# engine = create_engine('postgresql://postgres:Tata%40890@localhost/ids_database')

# %% [markdown]
# ## 1. The World Bank's international debt data

# %%
# %%sql
#
# SELECT *
# FROM debt_stat
# WHERE debt_2024 IS NOT NULL
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/ids_database
# 10 rows affected.
# [('Afghanistan', 'AFG', 'DT.TDS.DEGG.CD', 'Debt service on external debt, general government sector (PPG) (TDS, current US$)', 11680274.6, 21248292.7, 27416416.2, 30269882.9, 30597878.7, 32675060.7, 32780041.6, 28700402.1, 19234000.0, 12017000.0, 122856061.3, 126654245.8),
#  ('Afghanistan', 'AFG', 'DT.TDS.DLXF.CD', 'Debt service on external debt, long-term (TDS, current US$)', 11680274.6, 21248292.7, 33686416.2, 35219882.9, 35877878.7, 39785060.7, 39807041.6, 34557402.1, 19234000.0, 12017000.0, 128425061.3, 130601245.8),
#  ('Afghanistan', 'AFG', 'DT.TDS.DPNG.CD', 'Debt service on external debt, private nonguaranteed (PNG) (TDS, current US$)', None, None, 6270000.0, 4950000.0, 5280000.0, 7110000.0, 7027000.0, 5857000.0, None, None, 5569000.0, 3947000.0),
#  ('Afghanistan', 'AFG', 'DT.TDS.DPPG.CD', 'Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)', 11680274.6, 21248292.7, 27416416.2, 30269882.9, 30597878.7, 32675060.7, 32780041.6, 28700402.1, 19234000.0, 12017000.0, 122856061.3, 126654245.8),
#  ('Afghanistan', 'AFG', 'DT.TDS.DEPS.CD', 'Debt service on external debt, public sector (PPG) (TDS, current US$)', 11680274.6, 21248292.7, 27416416.2, 30269882.9, 30597878.7, 32675060.7, 32780041.6, 28700402.1, 19234000.0, 12017000.0, 122856061.3, 126654245.8),
#  ('Afghanistan', 'AFG', 'DT.TDS.DECT.CD', 'Debt service on external debt, total (TDS, current US$)', 25088493.4, 42203307.6, 56234850.6, 59621162.6, 63232789.7, 63115845.8, 55575662.9, 45904311.7, 25997304.5, 25678957.7, 132617219.2, 137188922.5),
#  ('Afghanistan', 'AFG', 'DT.DIS.DLXF.CD', 'Disbursements on external debt, long-term (DIS, current US$)', 36630750.0, 31740710.4, 26037493.8, 11669646.0, 3241563.2, 16323196.4, 28590201.1, 440209.2, 0.0, 0.0, 82455622.7, 100072671.6),
#  ('Afghanistan', 'AFG', 'DT.DIS.DPPG.CD', 'Disbursements on external debt, public and publicly guaranteed (PPG) (DIS, current US$)', 36630750.0, 31740710.4, 26037493.8, 11669646.0, 3241563.2, 16323196.4, 28590201.1, 440209.2, 0.0, 0.0, 82455622.7, 100072671.6),
#  ('Afghanistan', 'AFG', 'DT.AMT.BLAT.GG.CD', 'GG, bilateral (AMT, current US$)', None, 1983333.3, 2233333.3, 3100000.0, 2233600.0, 3316666.6, 4400000.0, 500000.0, None, None, 50505804.5, 50505804.5),
#  ('Afghanistan', 'AFG', 'DT.INT.BLAT.GG.CD', 'GG, bilateral (INT, current US$)', None, None, None, 56266.4, 112084.1, 112601.3, 111985.4, 55514.4, None, None, 20199826.3, 17544759.6)]

# %% [markdown]
# ## 2. Finding the number of distinct countries

# %%
# %%sql
#
# SELECT
#     COUNT(DISTINCT(country_name)) AS total_distinct_countries
# FROM debt_stat
# WHERE debt_2024 IS NOT NULL;
# Out:
#  * postgresql://postgres:***@localhost/ids_database
# 1 rows affected.
# [(122,)]

# %%
# %%sql
#
# select distinct(country_name)
# from debt_stat;
# Out:
#  * postgresql://postgres:***@localhost/ids_database
# 122 rows affected.
# [('Indonesia',),
#  ('Bangladesh',),
#  ('Iran, Islamic Rep.',),
#  ('Cameroon',),
#  ('Viet Nam',),
#  ('St. Lucia',),
#  ('Uganda',),
#  ('Montenegro',),
#  ('Jordan',),
#  ('Syrian Arab Republic',),
#  ('Dominican Republic',),
#  ('Cambodia',),
#  ('Papua New Guinea',),
#  ('Sri Lanka',),
#  ('Uzbekistan',),
#  ('Colombia',),
#  ('Albania',),
#  ('Ukraine',),
#  ('Grenada',),
#  ('Sao Tome and Principe',),
#  ("Cote d'Ivoire",),
#  ('Turkiye',),
#  ('Algeria',),
#  ('Maldives',),
#  ('Djibouti',),
#  ('Senegal',),
#  ('Kenya',),
#  ('Ghana',),
#  ('Zambia',),
#  ('Madagascar',),
#  ('Sierra Leone',),
#  ('Liberia',),
#  ('Bosnia and Herzegovina',),
#  ('Philippines',),
#  ('Benin',),
#  ('Cabo Verde',),
#  ('Guinea',),
#  ('Nigeria',),
#  ('Rwanda',),
#  ('Tajikistan',),
#  ('Zimbabwe',),
#  ('Congo, Rep.',),
#  ('Comoros',),
#  ('China',),
#  ('Belarus',),
#  ('Armenia',),
#  ('Lesotho',),
#  ('Paraguay',),
#  ('Gabon',),
#  ('Dominica',),
#  ('Serbia',),
#  ('Mauritius',),
#  ('Angola',),
#  ('Gambia, The',),
#  ('Vanuatu',),
#  ('Georgia',),
#  ('Malawi',),
#  ('Burundi',),
#  ('Bhutan',),
#  ('Solomon Islands',),
#  ('Thailand',),
#  ('Togo',),
#  ('Burkina Faso',),
#  ('El Salvador',),
#  ('Eswatini',),
#  ('Fiji',),
#  ('Congo, Dem. Rep.',),
#  ('Eritrea',),
#  ('Argentina',),
#  ('Egypt, Arab Rep.',),
#  ('Azerbaijan',),
#  ('Afghanistan',),
#  ('India',),
#  ('Chad',),
#  ('Timor-Leste',),
#  ('Kyrgyz Republic',),
#  ('South Africa',),
#  ('Suriname',),
#  ('Peru',),
#  ('Kazakhstan',),
#  ('Central African Republic',),
#  ('Kosovo',),
#  ('Jamaica',),
#  ('Yemen, Rep.',),
#  ('Mongolia',),
#  ('Iraq',),
#  ('Mauritania',),
#  ('Mozambique',),
#  ('Ecuador',),
#  ('Honduras',),
#  ('Belize',),
#  ('Botswana',),
#  ('Russian Federation',),
#  ('Pakistan',),
#  ('Brazil',),
#  ('Guatemala',),
#  ('Guinea-Bissau',),
#  ('Bolivia',),
#  ('Ethiopia',),
#  ('Niger',),
#  ('Bulgaria',),
#  ('Lao PDR',),
#  ('Turkmenistan',),
#  ('Tunisia',),
#  ('Sudan',),
#  ('Mali',),
#  ('North Macedonia',),
#  ('Morocco',),
#  ('Moldova',),
#  ('Myanmar',),
#  ('St. Vincent and the Grenadines',),
#  ('Nicaragua',),
#  ('Mexico',),
#  ('Tonga',),
#  ('Guyana',),
#  ('Nepal',),
#  ('Tanzania',),
#  ('Lebanon',),
#  ('Costa Rica',),
#  ('Haiti',),
#  ('Samoa',),
#  ('Somalia',)]

# %% [markdown]
# ## 3. Finding out the distinct debt indicators

# %%
# %%sql
#
# SELECT
#     DISTINCT(indicator_code) as distinct_debt_indicators
# FROM debt_stat
# GROUP BY distinct_debt_indicators
# ORDER BY distinct_debt_indicators;
# Out:
#  * postgresql://postgres:***@localhost/ids_database
# 572 rows affected.
# [('BM.GSR.TOTL.CD',),
#  ('BN.CAB.XOKA.CD',),
#  ('BX.GRT.EXTA.CD.DT',),
#  ('BX.GRT.TECH.CD.DT',),
#  ('BX.GSR.TOTL.CD',),
#  ('BX.KLT.DINV.CD.DT',),
#  ('BX.KLT.DREM.CD.DT',),
#  ('BX.PEF.TOTL.CD.DT',),
#  ('BX.TRF.PWKR.CD.DT',),
#  ('DT.AMT.BLAT.CB.CD',),
#  ('DT.AMT.BLAT.CD',),
#  ('DT.AMT.BLAT.GG.CD',),
#  ('DT.AMT.BLAT.OPS.CD',),
#  ('DT.AMT.BLAT.PRVG.CD',),
#  ('DT.AMT.BLAT.PS.CD',),
#  ('DT.AMT.BLTC.CB.CD',),
#  ('DT.AMT.BLTC.CD',),
#  ('DT.AMT.BLTC.GG.CD',),
#  ('DT.AMT.BLTC.OPS.CD',),
#  ('DT.AMT.BLTC.PRVG.CD',),
#  ('DT.AMT.BLTC.PS.CD',),
#  ('DT.AMT.DECB.CD',),
#  ('DT.AMT.DEGG.CD',),
#  ('DT.AMT.DEPS.CD',),
#  ('DT.AMT.DIMF.CD',),
#  ('DT.AMT.DLTF.CD',),
#  ('DT.AMT.DLXF.CD',),
#  ('DT.AMT.DOPS.CD',),
#  ('DT.AMT.DPNG.CD',),
#  ('DT.AMT.DPPG.CD',),
#  ('DT.AMT.MIBR.CD',),
#  ('DT.AMT.MIDA.CD',),
#  ('DT.AMT.MLAT.CB.CD',),
#  ('DT.AMT.MLAT.CD',),
#  ('DT.AMT.MLAT.GG.CD',),
#  ('DT.AMT.MLAT.OPS.CD',),
#  ('DT.AMT.MLAT.PRVG.CD',),
#  ('DT.AMT.MLAT.PS.CD',),
#  ('DT.AMT.MLTC.CB.CD',),
#  ('DT.AMT.MLTC.CD',),
#  ('DT.AMT.MLTC.GG.CD',),
#  ('DT.AMT.MLTC.OPS.CD',),
#  ('DT.AMT.MLTC.PRVG.CD',),
#  ('DT.AMT.MLTC.PS.CD',),
#  ('DT.AMT.OFFT.CB.CD',),
#  ('DT.AMT.OFFT.CD',),
#  ('DT.AMT.OFFT.GG.CD',),
#  ('DT.AMT.OFFT.OPS.CD',),
#  ('DT.AMT.OFFT.PRVG.CD',),
#  ('DT.AMT.OFFT.PS.CD',),
#  ('DT.AMT.PBND.CB.CD',),
#  ('DT.AMT.PBND.CD',),
#  ('DT.AMT.PBND.GG.CD',),
#  ('DT.AMT.PBND.OPS.CD',),
#  ('DT.AMT.PBND.PRVG.CD',),
#  ('DT.AMT.PBND.PS.CD',),
#  ('DT.AMT.PCBK.CB.CD',),
#  ('DT.AMT.PCBK.CD',),
#  ('DT.AMT.PCBK.GG.CD',),
#  ('DT.AMT.PCBK.OPS.CD',),
#  ('DT.AMT.PCBK.PRVG.CD',),
#  ('DT.AMT.PCBK.PS.CD',),
#  ('DT.AMT.PNGB.CD',),
#  ('DT.AMT.PNGC.CD',),
#  ('DT.AMT.PROP.CB.CD',),
#  ('DT.AMT.PROP.CD',),
#  ('DT.AMT.PROP.GG.CD',),
#  ('DT.AMT.PROP.OPS.CD',),
#  ('DT.AMT.PROP.PRVG.CD',),
#  ('DT.AMT.PROP.PS.CD',),
#  ('DT.AMT.PRPG.CD',),
#  ('DT.AMT.PRVT.CB.CD',),
#  ('DT.AMT.PRVT.CD',),
#  ('DT.AMT.PRVT.GG.CD',),
#  ('DT.AMT.PRVT.OPS.CD',),
#  ('DT.AMT.PRVT.PRVG.CD',),
#  ('DT.AMT.PRVT.PS.CD',),
#  ('DT.AXA.DLXF.CD',),
#  ('DT.AXA.OFFT.CD',),
#  ('DT.AXA.PRVT.CD',),
#  ('DT.AXF.DPPG.CD',),
#  ('DT.AXR.DPPG.CD',),
#  ('DT.AXR.OFFT.CD',),
#  ('DT.AXR.PRVT.CD',),
#  ('DT.COM.BLAT.CD',),
#  ('DT.COM.DPPG.CD',),
#  ('DT.COM.MIBR.CD',),
#  ('DT.COM.MIDA.CD',),
#  ('DT.COM.MLAT.CD',),
#  ('DT.COM.OFFT.CD',),
#  ('DT.COM.PRVT.CD',),
#  ('DT.CUR.DMAK.ZS',),
#  ('DT.CUR.EURO.ZS',),
#  ('DT.CUR.FFRC.ZS',),
#  ('DT.CUR.JYEN.ZS',),
#  ('DT.CUR.MULC.ZS',),
#  ('DT.CUR.OTHC.ZS',),
#  ('DT.CUR.SDRW.ZS',),
#  ('DT.CUR.SWFR.ZS',),
#  ('DT.CUR.UKPS.ZS',),
#  ('DT.CUR.USDL.ZS',),
#  ('DT.DFR.DPPG.CD',),
#  ('DT.DIS.BLAT.CB.CD',),
#  ('DT.DIS.BLAT.CD',),
#  ('DT.DIS.BLAT.GG.CD',),
#  ('DT.DIS.BLAT.OPS.CD',),
#  ('DT.DIS.BLAT.PRVG.CD',),
#  ('DT.DIS.BLAT.PS.CD',),
#  ('DT.DIS.BLTC.CB.CD',),
#  ('DT.DIS.BLTC.CD',),
#  ('DT.DIS.BLTC.GG.CD',),
#  ('DT.DIS.BLTC.OPS.CD',),
#  ('DT.DIS.BLTC.PRVG.CD',),
#  ('DT.DIS.BLTC.PS.CD',),
#  ('DT.DIS.DECB.CD',),
#  ('DT.DIS.DEGG.CD',),
#  ('DT.DIS.DEPS.CD',),
#  ('DT.DIS.DIMF.CD',),
#  ('DT.DIS.DLTF.CD',),
#  ('DT.DIS.DLXF.CD',),
#  ('DT.DIS.DOPS.CD',),
#  ('DT.DIS.DPNG.CD',),
#  ('DT.DIS.DPPG.CD',),
#  ('DT.DIS.IDAG.CD',),
#  ('DT.DIS.MIBR.CD',),
#  ('DT.DIS.MIDA.CD',),
#  ('DT.DIS.MLAT.CB.CD',),
#  ('DT.DIS.MLAT.CD',),
#  ('DT.DIS.MLAT.GG.CD',),
#  ('DT.DIS.MLAT.OPS.CD',),
#  ('DT.DIS.MLAT.PRVG.CD',),
#  ('DT.DIS.MLAT.PS.CD',),
#  ('DT.DIS.MLTC.CB.CD',),
#  ('DT.DIS.MLTC.CD',),
#  ('DT.DIS.MLTC.GG.CD',),
#  ('DT.DIS.MLTC.OPS.CD',),
#  ('DT.DIS.MLTC.PRVG.CD',),
#  ('DT.DIS.MLTC.PS.CD',),
#  ('DT.DIS.OFFT.CB.CD',),
#  ('DT.DIS.OFFT.CD',),
#  ('DT.DIS.OFFT.GG.CD',),
#  ('DT.DIS.OFFT.OPS.CD',),
#  ('DT.DIS.OFFT.PRVG.CD',),
#  ('DT.DIS.OFFT.PS.CD',),
#  ('DT.DIS.PBND.CB.CD',),
#  ('DT.DIS.PBND.CD',),
#  ('DT.DIS.PBND.GG.CD',),
#  ('DT.DIS.PBND.OPS.CD',),
#  ('DT.DIS.PBND.PRVG.CD',),
#  ('DT.DIS.PBND.PS.CD',),
#  ('DT.DIS.PCBK.CB.CD',),
#  ('DT.DIS.PCBK.CD',),
#  ('DT.DIS.PCBK.GG.CD',),
#  ('DT.DIS.PCBK.OPS.CD',),
#  ('DT.DIS.PCBK.PRVG.CD',),
#  ('DT.DIS.PCBK.PS.CD',),
#  ('DT.DIS.PNGB.CD',),
#  ('DT.DIS.PNGC.CD',),
#  ('DT.DIS.PROP.CB.CD',),
#  ('DT.DIS.PROP.CD',),
#  ('DT.DIS.PROP.GG.CD',),
#  ('DT.DIS.PROP.OPS.CD',),
#  ('DT.DIS.PROP.PRVG.CD',),
#  ('DT.DIS.PROP.PS.CD',),
#  ('DT.DIS.PRPG.CD',),
#  ('DT.DIS.PRVT.CB.CD',),
#  ('DT.DIS.PRVT.CD',),
#  ('DT.DIS.PRVT.GG.CD',),
#  ('DT.DIS.PRVT.OPS.CD',),
#  ('DT.DIS.PRVT.PRVG.CD',),
#  ('DT.DIS.PRVT.PS.CD',),
#  ('DT.DOD.ALLC.CD',),
#  ('DT.DOD.ALLC.ZS',),
#  ('DT.DOD.BLAT.CB.CD',),
#  ('DT.DOD.BLAT.CD',),
#  ('DT.DOD.BLAT.GG.CD',),
#  ('DT.DOD.BLAT.OPS.CD',),
#  ('DT.DOD.BLAT.PRVG.CD',),
#  ('DT.DOD.BLAT.PS.CD',),
#  ('DT.DOD.BLTC.CB.CD',),
#  ('DT.DOD.BLTC.CD',),
#  ('DT.DOD.BLTC.GG.CD',),
#  ('DT.DOD.BLTC.OPS.CD',),
#  ('DT.DOD.BLTC.PRVG.CD',),
#  ('DT.DOD.BLTC.PS.CD',),
#  ('DT.DOD.DECB.CD',),
#  ('DT.DOD.DECT.CD',),
#  ('DT.DOD.DECT.CD.CG',),
#  ('DT.DOD.DECT.EX.ZS',),
#  ('DT.DOD.DECT.GN.ZS',),
#  ('DT.DOD.DECT.PC.CD',),
#  ('DT.DOD.DEGG.CD',),
#  ('DT.DOD.DEPS.CD',),
#  ('DT.DOD.DIMF.CD',),
#  ('DT.DOD.DIMF.US.CD',),
#  ('DT.DOD.DLXF.CD',),
#  ('DT.DOD.DOPS.CD',),
#  ('DT.DOD.DPNG.CD',),
#  ('DT.DOD.DPPG.CD',),
#  ('DT.DOD.DSDR.CD',),
#  ('DT.DOD.DSTC.CD',),
#  ('DT.DOD.DSTC.ZS',),
#  ('DT.DOD.MDRI.CD',),
#  ('DT.DOD.MIBR.CD',),
#  ('DT.DOD.MIDA.CD',),
#  ('DT.DOD.MLAT.CB.CD',),
#  ('DT.DOD.MLAT.CD',),
#  ('DT.DOD.MLAT.GG.CD',),
#  ('DT.DOD.MLAT.OPS.CD',),
#  ('DT.DOD.MLAT.PRVG.CD',),
#  ('DT.DOD.MLAT.PS.CD',),
#  ('DT.DOD.MLAT.ZS',),
#  ('DT.DOD.MLTC.CB.CD',),
#  ('DT.DOD.MLTC.CD',),
#  ('DT.DOD.MLTC.GG.CD',),
#  ('DT.DOD.MLTC.OPS.CD',),
#  ('DT.DOD.MLTC.PRVG.CD',),
#  ('DT.DOD.MLTC.PS.CD',),
#  ('DT.DOD.OFFT.CB.CD',),
#  ('DT.DOD.OFFT.CD',),
#  ('DT.DOD.OFFT.GG.CD',),
#  ('DT.DOD.OFFT.OPS.CD',),
#  ('DT.DOD.OFFT.PRVG.CD',),
#  ('DT.DOD.OFFT.PS.CD',),
#  ('DT.DOD.PBND.CB.CD',),
#  ('DT.DOD.PBND.CD',),
#  ('DT.DOD.PBND.GG.CD',),
#  ('DT.DOD.PBND.OPS.CD',),
#  ('DT.DOD.PBND.PRVG.CD',),
#  ('DT.DOD.PBND.PS.CD',),
#  ('DT.DOD.PCBK.CB.CD',),
#  ('DT.DOD.PCBK.CD',),
#  ('DT.DOD.PCBK.GG.CD',),
#  ('DT.DOD.PCBK.OPS.CD',),
#  ('DT.DOD.PCBK.PRVG.CD',),
#  ('DT.DOD.PCBK.PS.CD',),
#  ('DT.DOD.PNGB.CD',),
#  ('DT.DOD.PNGC.CD',),
#  ('DT.DOD.PROP.CB.CD',),
#  ('DT.DOD.PROP.CD',),
#  ('DT.DOD.PROP.GG.CD',),
#  ('DT.DOD.PROP.OPS.CD',),
#  ('DT.DOD.PROP.PRVG.CD',),
#  ('DT.DOD.PROP.PS.CD',),
#  ('DT.DOD.PRPG.CD',),
#  ('DT.DOD.PRVS.CD',),
#  ('DT.DOD.PRVT.CB.CD',),
#  ('DT.DOD.PRVT.CD',),
#  ('DT.DOD.PRVT.GG.CD',),
#  ('DT.DOD.PRVT.OPS.CD',),
#  ('DT.DOD.PRVT.PRVG.CD',),
#  ('DT.DOD.PRVT.PS.CD',),
#  ('DT.DOD.PUBS.CD',),
#  ('DT.DOD.PVLX.CD',),
#  ('DT.DOD.PVLX.EX.ZS',),
#  ('DT.DOD.PVLX.GN.ZS',),
#  ('DT.DOD.RSDL.CD',),
#  ('DT.DOD.VTOT.CD',),
#  ('DT.DSB.DPPG.CD',),
#  ('DT.DSF.DPPG.CD',),
#  ('DT.DXR.DPPG.CD',),
#  ('DT.GPA.DPPG',),
#  ('DT.GPA.OFFT',),
#  ('DT.GPA.PRVT',),
#  ('DT.GRE.DPPG',),
#  ('DT.GRE.OFFT',),
#  ('DT.GRE.PRVT',),
#  ('DT.INR.DPPG',),
#  ('DT.INR.OFFT',),
#  ('DT.INR.PRVT',),
#  ('DT.INT.BLAT.CB.CD',),
#  ('DT.INT.BLAT.CD',),
#  ('DT.INT.BLAT.GG.CD',),
#  ('DT.INT.BLAT.OPS.CD',),
#  ('DT.INT.BLAT.PRVG.CD',),
#  ('DT.INT.BLAT.PS.CD',),
#  ('DT.INT.BLTC.CB.CD',),
#  ('DT.INT.BLTC.CD',),
#  ('DT.INT.BLTC.GG.CD',),
#  ('DT.INT.BLTC.OPS.CD',),
#  ('DT.INT.BLTC.PRVG.CD',),
#  ('DT.INT.BLTC.PS.CD',),
#  ('DT.INT.DECB.CD',),
#  ('DT.INT.DECT.CD',),
#  ('DT.INT.DECT.EX.ZS',),
#  ('DT.INT.DECT.GN.ZS',),
#  ('DT.INT.DEGG.CD',),
#  ('DT.INT.DEPS.CD',),
#  ('DT.INT.DIMF.CD',),
#  ('DT.INT.DLXF.CD',),
#  ('DT.INT.DOPS.CD',),
#  ('DT.INT.DPNG.CD',),
#  ('DT.INT.DPPG.CD',),
#  ('DT.INT.DSTC.CD',),
#  ('DT.INT.MIBR.CD',),
#  ('DT.INT.MIDA.CD',),
#  ('DT.INT.MLAT.CB.CD',),
#  ('DT.INT.MLAT.CD',),
#  ('DT.INT.MLAT.GG.CD',),
#  ('DT.INT.MLAT.OPS.CD',),
#  ('DT.INT.MLAT.PRVG.CD',),
#  ('DT.INT.MLAT.PS.CD',),
#  ('DT.INT.MLTC.CB.CD',),
#  ('DT.INT.MLTC.CD',),
#  ('DT.INT.MLTC.GG.CD',),
#  ('DT.INT.MLTC.OPS.CD',),
#  ('DT.INT.MLTC.PRVG.CD',),
#  ('DT.INT.MLTC.PS.CD',),
#  ('DT.INT.OFFT.CB.CD',),
#  ('DT.INT.OFFT.CD',),
#  ('DT.INT.OFFT.GG.CD',),
#  ('DT.INT.OFFT.OPS.CD',),
#  ('DT.INT.OFFT.PRVG.CD',),
#  ('DT.INT.OFFT.PS.CD',),
#  ('DT.INT.PBND.CB.CD',),
#  ('DT.INT.PBND.CD',),
#  ('DT.INT.PBND.GG.CD',),
#  ('DT.INT.PBND.OPS.CD',),
#  ('DT.INT.PBND.PRVG.CD',),
#  ('DT.INT.PBND.PS.CD',),
#  ('DT.INT.PCBK.CB.CD',),
#  ('DT.INT.PCBK.CD',),
#  ('DT.INT.PCBK.GG.CD',),
#  ('DT.INT.PCBK.OPS.CD',),
#  ('DT.INT.PCBK.PRVG.CD',),
#  ('DT.INT.PCBK.PS.CD',),
#  ('DT.INT.PNGB.CD',),
#  ('DT.INT.PNGC.CD',),
#  ('DT.INT.PROP.CB.CD',),
#  ('DT.INT.PROP.CD',),
#  ('DT.INT.PROP.GG.CD',),
#  ('DT.INT.PROP.OPS.CD',),
#  ('DT.INT.PROP.PRVG.CD',),
#  ('DT.INT.PROP.PS.CD',),
#  ('DT.INT.PRPG.CD',),
#  ('DT.INT.PRVT.CB.CD',),
#  ('DT.INT.PRVT.CD',),
#  ('DT.INT.PRVT.GG.CD',),
#  ('DT.INT.PRVT.OPS.CD',),
#  ('DT.INT.PRVT.PRVG.CD',),
#  ('DT.INT.PRVT.PS.CD',),
#  ('DT.IXA.DLXF.CD',),
#  ('DT.IXA.DPPG.CD.CG',),
#  ('DT.IXA.OFFT.CD',),
#  ('DT.IXA.PRVT.CD',),
#  ('DT.IXF.DPPG.CD',),
#  ('DT.IXR.DPPG.CD',),
#  ('DT.IXR.OFFT.CD',),
#  ('DT.IXR.PRVT.CD',),
#  ('DT.MAT.DPPG',),
#  ('DT.MAT.OFFT',),
#  ('DT.MAT.PRVT',),
#  ('DT.NFL.BLAT.CB.CD',),
#  ('DT.NFL.BLAT.CD',),
#  ('DT.NFL.BLAT.GG.CD',),
#  ('DT.NFL.BLAT.OPS.CD',),
#  ('DT.NFL.BLAT.PRVG.CD',),
#  ('DT.NFL.BLAT.PS.CD',),
#  ('DT.NFL.BLTC.CB.CD',),
#  ('DT.NFL.BLTC.CD',),
#  ('DT.NFL.BLTC.GG.CD',),
#  ('DT.NFL.BLTC.OPS.CD',),
#  ('DT.NFL.BLTC.PRVG.CD',),
#  ('DT.NFL.BLTC.PS.CD',),
#  ('DT.NFL.DECB.CD',),
#  ('DT.NFL.DECT.CD',),
#  ('DT.NFL.DEGG.CD',),
#  ('DT.NFL.DEPS.CD',),
#  ('DT.NFL.DLXF.CD',),
#  ('DT.NFL.DOPS.CD',),
#  ('DT.NFL.DPNG.CD',),
#  ('DT.NFL.DPPG.CD',),
#  ('DT.NFL.DSTC.CD',),
#  ('DT.NFL.IMFC.CD',),
#  ('DT.NFL.IMFN.CD',),
#  ('DT.NFL.MIBR.CD',),
#  ('DT.NFL.MIDA.CD',),
#  ('DT.NFL.MLAT.CB.CD',),
#  ('DT.NFL.MLAT.CD',),
#  ('DT.NFL.MLAT.GG.CD',),
#  ('DT.NFL.MLAT.OPS.CD',),
#  ('DT.NFL.MLAT.PRVG.CD',),
#  ('DT.NFL.MLAT.PS.CD',),
#  ('DT.NFL.MLTC.CB.CD',),
#  ('DT.NFL.MLTC.CD',),
#  ('DT.NFL.MLTC.GG.CD',),
#  ('DT.NFL.MLTC.OPS.CD',),
#  ('DT.NFL.MLTC.PRVG.CD',),
#  ('DT.NFL.MLTC.PS.CD',),
#  ('DT.NFL.MOTH.CD',),
#  ('DT.NFL.NEBR.CD',),
#  ('DT.NFL.NIFC.CD',),
#  ('DT.NFL.OFFT.CB.CD',),
#  ('DT.NFL.OFFT.CD',),
#  ('DT.NFL.OFFT.GG.CD',),
#  ('DT.NFL.OFFT.OPS.CD',),
#  ('DT.NFL.OFFT.PRVG.CD',),
#  ('DT.NFL.OFFT.PS.CD',),
#  ('DT.NFL.PBND.CB.CD',),
#  ('DT.NFL.PBND.CD',),
#  ('DT.NFL.PBND.GG.CD',),
#  ('DT.NFL.PBND.OPS.CD',),
#  ('DT.NFL.PBND.PRVG.CD',),
#  ('DT.NFL.PBND.PS.CD',),
#  ('DT.NFL.PCBK.CB.CD',),
#  ('DT.NFL.PCBK.CD',),
#  ('DT.NFL.PCBK.GG.CD',),
#  ('DT.NFL.PCBK.OPS.CD',),
#  ('DT.NFL.PCBK.PRVG.CD',),
#  ('DT.NFL.PCBK.PS.CD',),
#  ('DT.NFL.PNGB.CD',),
#  ('DT.NFL.PNGC.CD',),
#  ('DT.NFL.PROP.CB.CD',),
#  ('DT.NFL.PROP.CD',),
#  ('DT.NFL.PROP.GG.CD',),
#  ('DT.NFL.PROP.OPS.CD',),
#  ('DT.NFL.PROP.PRVG.CD',),
#  ('DT.NFL.PROP.PS.CD',),
#  ('DT.NFL.PRPG.CD',),
#  ('DT.NFL.PRVT.CB.CD',),
#  ('DT.NFL.PRVT.CD',),
#  ('DT.NFL.PRVT.GG.CD',),
#  ('DT.NFL.PRVT.OPS.CD',),
#  ('DT.NFL.PRVT.PRVG.CD',),
#  ('DT.NFL.PRVT.PS.CD',),
#  ('DT.NFL.RDBC.CD',),
#  ('DT.NFL.RDBN.CD',),
#  ('DT.NTR.BLAT.CB.CD',),
#  ('DT.NTR.BLAT.CD',),
#  ('DT.NTR.BLAT.GG.CD',),
#  ('DT.NTR.BLAT.OPS.CD',),
#  ('DT.NTR.BLAT.PRVG.CD',),
#  ('DT.NTR.BLAT.PS.CD',),
#  ('DT.NTR.BLTC.CB.CD',),
#  ('DT.NTR.BLTC.CD',),
#  ('DT.NTR.BLTC.GG.CD',),
#  ('DT.NTR.BLTC.OPS.CD',),
#  ('DT.NTR.BLTC.PRVG.CD',),
#  ('DT.NTR.BLTC.PS.CD',),
#  ('DT.NTR.DECB.CD',),
#  ('DT.NTR.DECT.CD',),
#  ('DT.NTR.DEGG.CD',),
#  ('DT.NTR.DEPS.CD',),
#  ('DT.NTR.DLXF.CD',),
#  ('DT.NTR.DOPS.CD',),
#  ('DT.NTR.DPNG.CD',),
#  ('DT.NTR.DPPG.CD',),
#  ('DT.NTR.MIBR.CD',),
#  ('DT.NTR.MIDA.CD',),
#  ('DT.NTR.MLAT.CB.CD',),
#  ('DT.NTR.MLAT.CD',),
#  ('DT.NTR.MLAT.GG.CD',),
#  ('DT.NTR.MLAT.OPS.CD',),
#  ('DT.NTR.MLAT.PRVG.CD',),
#  ('DT.NTR.MLAT.PS.CD',),
#  ('DT.NTR.MLTC.CB.CD',),
#  ('DT.NTR.MLTC.CD',),
#  ('DT.NTR.MLTC.GG.CD',),
#  ('DT.NTR.MLTC.OPS.CD',),
#  ('DT.NTR.MLTC.PRVG.CD',),
#  ('DT.NTR.MLTC.PS.CD',),
#  ('DT.NTR.OFFT.CB.CD',),
#  ('DT.NTR.OFFT.CD',),
#  ('DT.NTR.OFFT.GG.CD',),
#  ('DT.NTR.OFFT.OPS.CD',),
#  ('DT.NTR.OFFT.PRVG.CD',),
#  ('DT.NTR.OFFT.PS.CD',),
#  ('DT.NTR.PBND.CB.CD',),
#  ('DT.NTR.PBND.CD',),
#  ('DT.NTR.PBND.GG.CD',),
#  ('DT.NTR.PBND.OPS.CD',),
#  ('DT.NTR.PBND.PRVG.CD',),
#  ('DT.NTR.PBND.PS.CD',),
#  ('DT.NTR.PCBK.CB.CD',),
#  ('DT.NTR.PCBK.CD',),
#  ('DT.NTR.PCBK.GG.CD',),
#  ('DT.NTR.PCBK.OPS.CD',),
#  ('DT.NTR.PCBK.PRVG.CD',),
#  ('DT.NTR.PCBK.PS.CD',),
#  ('DT.NTR.PNGB.CD',),
#  ('DT.NTR.PNGC.CD',),
#  ('DT.NTR.PROP.CB.CD',),
#  ('DT.NTR.PROP.CD',),
#  ('DT.NTR.PROP.GG.CD',),
#  ('DT.NTR.PROP.OPS.CD',),
#  ('DT.NTR.PROP.PRVG.CD',),
#  ('DT.NTR.PROP.PS.CD',),
#  ('DT.NTR.PRPG.CD',),
#  ('DT.NTR.PRVT.CB.CD',),
#  ('DT.NTR.PRVT.CD',),
#  ('DT.NTR.PRVT.GG.CD',),
#  ('DT.NTR.PRVT.OPS.CD',),
#  ('DT.NTR.PRVT.PRVG.CD',),
#  ('DT.NTR.PRVT.PS.CD',),
#  ('DT.TDS.BLAT.CB.CD',),
#  ('DT.TDS.BLAT.CD',),
#  ('DT.TDS.BLAT.GG.CD',),
#  ('DT.TDS.BLAT.OPS.CD',),
#  ('DT.TDS.BLAT.PRVG.CD',),
#  ('DT.TDS.BLAT.PS.CD',),
#  ('DT.TDS.BLTC.CB.CD',),
#  ('DT.TDS.BLTC.CD',),
#  ('DT.TDS.BLTC.GG.CD',),
#  ('DT.TDS.BLTC.OPS.CD',),
#  ('DT.TDS.BLTC.PRVG.CD',),
#  ('DT.TDS.BLTC.PS.CD',),
#  ('DT.TDS.DECB.CD',),
#  ('DT.TDS.DECT.CD',),
#  ('DT.TDS.DECT.EX.ZS',),
#  ('DT.TDS.DEGG.CD',),
#  ('DT.TDS.DEPS.CD',),
#  ('DT.TDS.DIMF.CD',),
#  ('DT.TDS.DLXF.CD',),
#  ('DT.TDS.DOPS.CD',),
#  ('DT.TDS.DPNG.CD',),
#  ('DT.TDS.DPPG.CD',),
#  ('DT.TDS.MIBR.CD',),
#  ('DT.TDS.MIDA.CD',),
#  ('DT.TDS.MLAT.CB.CD',),
#  ('DT.TDS.MLAT.CD',),
#  ('DT.TDS.MLAT.GG.CD',),
#  ('DT.TDS.MLAT.OPS.CD',),
#  ('DT.TDS.MLAT.PRVG.CD',),
#  ('DT.TDS.MLAT.PS.CD',),
#  ('DT.TDS.MLTC.CB.CD',),
#  ('DT.TDS.MLTC.CD',),
#  ('DT.TDS.MLTC.GG.CD',),
#  ('DT.TDS.MLTC.OPS.CD',),
#  ('DT.TDS.MLTC.PRVG.CD',),
#  ('DT.TDS.MLTC.PS.CD',),
#  ('DT.TDS.OFFT.CB.CD',),
#  ('DT.TDS.OFFT.CD',),
#  ('DT.TDS.OFFT.GG.CD',),
#  ('DT.TDS.OFFT.OPS.CD',),
#  ('DT.TDS.OFFT.PRVG.CD',),
#  ('DT.TDS.OFFT.PS.CD',),
#  ('DT.TDS.PBND.CB.CD',),
#  ('DT.TDS.PBND.CD',),
#  ('DT.TDS.PBND.GG.CD',),
#  ('DT.TDS.PBND.OPS.CD',),
#  ('DT.TDS.PBND.PRVG.CD',),
#  ('DT.TDS.PBND.PS.CD',),
#  ('DT.TDS.PCBK.CB.CD',),
#  ('DT.TDS.PCBK.CD',),
#  ('DT.TDS.PCBK.GG.CD',),
#  ('DT.TDS.PCBK.OPS.CD',),
#  ('DT.TDS.PCBK.PRVG.CD',),
#  ('DT.TDS.PCBK.PS.CD',),
#  ('DT.TDS.PNGB.CD',),
#  ('DT.TDS.PNGC.CD',),
#  ('DT.TDS.PROP.CB.CD',),
#  ('DT.TDS.PROP.CD',),
#  ('DT.TDS.PROP.GG.CD',),
#  ('DT.TDS.PROP.OPS.CD',),
#  ('DT.TDS.PROP.PRVG.CD',),
#  ('DT.TDS.PROP.PS.CD',),
#  ('DT.TDS.PRPG.CD',),
#  ('DT.TDS.PRVT.CB.CD',),
#  ('DT.TDS.PRVT.CD',),
#  ('DT.TDS.PRVT.GG.CD',),
#  ('DT.TDS.PRVT.OPS.CD',),
#  ('DT.TDS.PRVT.PRVG.CD',),
#  ('DT.TDS.PRVT.PS.CD',),
#  ('DT.TXR.DPPG.CD',),
#  ('DT.UND.DPPG.CD',),
#  ('DT.UND.OFFT.CD',),
#  ('DT.UND.PRVT.CD',),
#  ('FI.RES.TOTL.CD',),
#  ('FI.RES.TOTL.DT.ZS',),
#  ('FI.RES.TOTL.MO',),
#  ('NY.GNP.MKTP.CD',),
#  ('SP.POP.TOTL',)]

# %% [markdown]
# ## 4. Total amount of debt owed by the countries in trillion USD

# %%
# %%sql
#
# SELECT
#     (SUM(debt_2024))/1000000000000 as total_debt
# FROM debt_stat;
# Out:
#  * postgresql://postgres:***@localhost/ids_database
# 1 rows affected.
# [(13.503656900614018,)]

# %% [markdown]
# ## 5. Top 10 countries with the highest debt in billion USD

# %%
# %%sql
#
# SELECT
#     country_name,
#     SUM(debt_2024)/1000000000 as total_debt
# FROM debt_stat
# GROUP BY country_name
# ORDER BY total_debt DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/ids_database
# 10 rows affected.
# [('China', 2119.1675967280003),
#  ('Mexico', 1061.442009101),
#  ('Indonesia', 976.8611320374997),
#  ('India', 958.3342452932),
#  ('Brazil', 931.5752632627001),
#  ('Turkiye', 711.0425423970004),
#  ('Russian Federation', 665.2637206996),
#  ('Egypt, Arab Rep.', 434.82536921509995),
#  ('Colombia', 280.5722073488999),
#  ('Kazakhstan', 255.99108512729993)]

# %% [markdown]
# ## 6. Average amount of debt across indicators in million USD

# %%
# %%sql
#
# SELECT
#     indicator_code AS debt_indicator,
#     indicator_name,
#     (AVG(debt_2024))/1000000 as average_debt
# FROM debt_stat
# WHERE debt_2024 IS NOT NULL
# GROUP BY debt_indicator, indicator_name
# ORDER BY average_debt DESC;
# Out:
#  * postgresql://postgres:***@localhost/ids_database
# 146 rows affected.
# [('DT.TDS.DECT.CD', 'Debt service on external debt, total (TDS, current US$)', 8357.224839814755),
#  ('DT.TDS.DLXF.CD', 'Debt service on external debt, long-term (TDS, current US$)', 8088.1133516262325),
#  ('DT.AMT.DLXF.CD', 'Principal repayments on external debt, long-term (AMT, current US$)', 6117.160279055738),
#  ('DT.TDS.DPNG.CD', 'Debt service on external debt, private nonguaranteed (PNG) (TDS, current US$)', 5983.117690598876),
#  ('DT.AMT.DPNG.CD', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', 4930.573084389888),
#  ('DT.TDS.PNGC.CD', 'PNG, commercial banks and other creditors (TDS, current US$)', 4873.233496026437),
#  ('DT.AMT.PNGC.CD', 'PNG, commercial banks and other creditors (AMT, current US$)', 4081.303092306897),
#  ('DT.TDS.DPPG.CD', 'Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)', 3723.379257870492),
#  ('DT.TDS.DEPS.CD', 'Debt service on external debt, public sector (PPG) (TDS, current US$)', 3699.2870664606558),
#  ('DT.TDS.PRVT.CD', 'PPG, private creditors (TDS, current US$)', 3020.5199224618555),
#  ('DT.TDS.PRVT.PS.CD', 'PS, private creditors (TDS, current US$)', 2993.069500296907),
#  ('DT.TDS.PBND.CD', 'PPG, bonds (TDS, current US$)', 2824.5933393541663),
#  ('DT.TDS.PBND.PS.CD', 'PS, bonds (TDS, current US$)', 2790.7017388541667),
#  ('DT.TDS.PRVT.OPS.CD', 'OPS, private creditors (TDS, current US$)', 2684.0798398106385),
#  ('DT.AMT.DPPG.CD', 'Principal repayments on external debt, public and publicly guaranteed (PPG) (AMT, current US$)', 2520.2690208106555),
#  ('DT.TDS.DEGG.CD', 'Debt service on external debt, general government sector (PPG) (TDS, current US$)', 2441.492335964754),
#  ('DT.TDS.PNGB.CD', 'PNG, bonds (TDS, current US$)', 2411.6878918177777),
#  ('DT.TDS.PBND.OPS.CD', 'OPS, bonds (TDS, current US$)', 2380.112411044),
#  ('DT.AMT.PRVT.OPS.CD', 'OPS, private creditors (AMT, current US$)', 2006.8887246297877),
#  ('DT.TDS.PBND.GG.CD', 'GG, bonds (TDS, current US$)', 2006.2023520214286),
#  ('DT.AMT.PRVT.CD', 'PPG, private creditors (AMT, current US$)', 1991.668420384536),
#  ('DT.INT.DLXF.CD', 'Interest payments on external debt, long-term (INT, current US$)', 1970.948472931967),
#  ('DT.AMT.PRVT.PS.CD', 'PS, private creditors (AMT, current US$)', 1970.0676283948453),
#  ('DT.AMT.PNGB.CD', 'PNG, bonds (AMT, current US$)', 1861.0585662066671),
#  ('DT.AMT.PBND.OPS.CD', 'OPS, bonds (AMT, current US$)', 1846.806326784),
#  ('DT.AMT.PBND.CD', 'PPG, bonds (AMT, current US$)', 1767.3731096958331),
#  ('DT.AMT.PBND.PS.CD', 'PS, bonds (AMT, current US$)', 1740.2716851680555),
#  ('DT.TDS.PRVT.GG.CD', 'GG, private creditors (TDS, current US$)', 1710.1936050978952),
#  ('DT.TDS.DOPS.CD', 'Debt service on external debt, other public sector (PPG) (TDS, current US$)', 1660.4887352842684),
#  ('DT.AMT.DEGG.CD', 'Principal repayments on external debt, general government sector (PPG) (AMT, current US$)', 1545.9959626852465),
#  ('DT.TDS.PCBK.OPS.CD', 'OPS, commercial banks (TDS, current US$)', 1490.2442647099997),
#  ('DT.DIS.DLXF.CD', 'Disbursements on external debt, long-term (DIS, current US$)', 1324.6586528374999),
#  ('DT.TDS.OFFT.PS.CD', 'PS, official creditors (TDS, current US$)', 1319.551480148361),
#  ('DT.DIS.DPPG.CD', 'Disbursements on external debt, public and publicly guaranteed (PPG) (DIS, current US$)', 1318.9948632299997),
#  ('DT.AMT.DOPS.CD', 'Principal repayments on external debt, other public sector (PPG) (AMT, current US$)', 1255.5425787640452),
#  ('DT.TDS.PBND.PRVG.CD', 'PRVG, bonds (TDS, current US$)', 1220.097618),
#  ('DT.INT.DPPG.CD', 'Interest payments on external debt, public and publicly guaranteed (PPG) (INT, current US$)', 1203.1102370549181),
#  ('DT.INT.DEPS.CD', 'Interest payments on external debt, public sector (PPG) (INT, current US$)', 1198.0374972688528),
#  ('DT.AMT.PCBK.OPS.CD', 'OPS, commercial banks (AMT, current US$)', 1138.089018955),
#  ('DT.DIS.OFFT.CD', 'PPG, official creditors (DIS, current US$)', 1130.2326510699995),
#  ('DT.AMT.PBND.GG.CD', 'GG, bonds (AMT, current US$)', 1117.468473742857),
#  ('DT.TDS.OFFT.GG.CD', 'GG, official creditors (TDS, current US$)', 1109.7842008491803),
#  ('DT.INT.PBND.CD', 'PPG, bonds (INT, current US$)', 1057.2202296805556),
#  ('DT.INT.DPNG.CD', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', 1052.5423008438202),
#  ('DT.INT.PBND.PS.CD', 'PS, bonds (INT, current US$)', 1050.4300537083334),
#  ('DT.INT.PRVT.CD', 'PPG, private creditors (INT, current US$)', 1028.8515020525774),
#  ('DT.INT.PRVT.PS.CD', 'PS, private creditors (INT, current US$)', 1023.0018718773197),
#  ('DT.AMT.PRVT.GG.CD', 'GG, private creditors (AMT, current US$)', 1003.9289800842105),
#  ('DT.AMT.PBND.PRVG.CD', 'PRVG, bonds (AMT, current US$)', 975.651283),
#  ('DT.TDS.PCBK.CD', 'PPG, commercial banks (TDS, current US$)', 957.7868398678569),
#  ('DT.TDS.PCBK.PS.CD', 'PS, commercial banks (TDS, current US$)', 955.1380813678569),
#  ('DT.AMT.OFFT.CD', 'PPG, official creditors (AMT, current US$)', 936.7293750663935),
#  ('DT.AMT.OFFT.PS.CD', 'PS, official creditors (AMT, current US$)', 934.8843236213115),
#  ('DT.INT.DEGG.CD', 'Interest payments on external debt, general government sector (PPG) (INT, current US$)', 895.4963733073771),
#  ('DT.INT.PBND.GG.CD', 'GG, bonds (INT, current US$)', 888.733878297143),
#  ('DT.TDS.MLAT.CD', 'Multilateral debt service (TDS, current US$)', 801.9258047467214),
#  ('DT.TDS.MLAT.PS.CD', 'PS, multilateral (TDS, current US$)', 800.072558752459),
#  ('DT.INT.PNGC.CD', 'PNG, commercial banks and other creditors (INT, current US$)', 791.9304037137931),
#  ('DT.AMT.OFFT.GG.CD', 'GG, official creditors (AMT, current US$)', 764.2479863696722),
#  ('DT.AMT.PCBK.CD', 'PPG, commercial banks (AMT, current US$)', 734.1082756011904),
#  ('DT.AMT.PCBK.PS.CD', 'PS, commercial banks (AMT, current US$)', 732.3942963392855),
#  ('DT.TDS.MLAT.GG.CD', 'GG, multilateral (TDS, current US$)', 713.5267619852459),
#  ('DT.INT.PRVT.GG.CD', 'GG, private creditors (INT, current US$)', 706.2646249873686),
#  ('DT.TDS.PROP.OPS.CD', 'OPS, other private creditors (TDS, current US$)', 703.9171609000001),
#  ('DT.INT.PRVT.OPS.CD', 'OPS, private creditors (INT, current US$)', 677.1911151978723),
#  ('DT.TDS.PRVT.PRVG.CD', 'PRVG, private creditors (TDS, current US$)', 665.67273735),
#  ('DT.DIS.MLAT.CD', 'PPG, multilateral (DIS, current US$)', 633.3647972589745),
#  ('DT.INT.PNGB.CD', 'PNG, bonds (INT, current US$)', 550.6293256111112),
#  ('DT.DIS.BLAT.CD', 'PPG, bilateral (DIS, current US$)', 539.6862881307018),
#  ('DT.INT.PBND.OPS.CD', 'OPS, bonds (INT, current US$)', 533.3060841719999),
#  ('DT.AMT.PRVT.PRVG.CD', 'PRVG, private creditors (AMT, current US$)', 523.819205825),
#  ('DT.AMT.MLAT.CD', 'PPG, multilateral (AMT, current US$)', 523.6914963163936),
#  ('DT.AMT.MLAT.PS.CD', 'PS, multilateral (AMT, current US$)', 522.1618402450821),
#  ('DT.TDS.BLAT.CD', 'PPG, bilateral (TDS, current US$)', 519.8925311500001),
#  ('DT.TDS.BLAT.PS.CD', 'PS, bilateral (TDS, current US$)', 519.4789213901639),
#  ('DT.AMT.MLAT.GG.CD', 'GG, multilateral (AMT, current US$)', 454.2695648385247),
#  ('DT.DIS.PRVT.CD', 'PPG, private creditors (DIS, current US$)', 444.1463816235295),
#  ('DT.INT.PROP.OPS.CD', 'OPS, other private creditors (INT, current US$)', 440.9120479900001),
#  ('DT.AMT.BLAT.CD', 'PPG, bilateral (AMT, current US$)', 413.03787875245916),
#  ('DT.AMT.BLAT.PS.CD', 'PS, bilateral (AMT, current US$)', 412.7224833844264),
#  ('DT.DIS.PCBK.CD', 'PPG, commercial banks (DIS, current US$)', 411.599025762),
#  ('DT.INT.DOPS.CD', 'Interest payments on external debt, other public sector (PPG) (INT, current US$)', 404.9461565269662),
#  ('DT.TDS.BLAT.GG.CD', 'GG, bilateral (TDS, current US$)', 399.5322937322313),
#  ('DT.INT.OFFT.CD', 'PPG, official creditors (INT, current US$)', 385.08896085655743),
#  ('DT.INT.OFFT.PS.CD', 'PS, official creditors (INT, current US$)', 384.66715652950825),
#  ('DT.INT.PCBK.OPS.CD', 'OPS, commercial banks (INT, current US$)', 352.155245745),
#  ('DT.INT.OFFT.GG.CD', 'GG, official creditors (INT, current US$)', 345.53621449098347),
#  ('DT.TDS.DIMF.CD', 'IMF repurchases and charges (TDS, current US$)', 324.98936196138607),
#  ('DT.AMT.BLAT.GG.CD', 'GG, bilateral (AMT, current US$)', 312.5402266768596),
#  ('DT.INT.MLAT.CD', 'PPG, multilateral (INT, current US$)', 278.2343084377049),
#  ('DT.INT.MLAT.PS.CD', 'PS, multilateral (INT, current US$)', 277.91071850409844),
#  ('DT.TDS.PCBK.GG.CD', 'GG, commercial banks (TDS, current US$)', 266.4295038973334),
#  ('DT.AMT.DIMF.CD', 'IMF repurchases (AMT, current US$)', 266.2981635267327),
#  ('DT.AMT.PROP.OPS.CD', 'OPS, other private creditors (AMT, current US$)', 263.00511295),
#  ('DT.TDS.PROP.PS.CD', 'PS, other private creditors (TDS, current US$)', 261.87478563714296),
#  ('DT.INT.MLAT.GG.CD', 'GG, multilateral (INT, current US$)', 259.25719716885254),
#  ('DT.TDS.OFFT.OPS.CD', 'OPS, official creditors (TDS, current US$)', 257.520773452381),
#  ('DT.INT.PBND.PRVG.CD', 'PRVG, bonds (INT, current US$)', 244.446335),
#  ('DT.INT.PCBK.CD', 'PPG, commercial banks (INT, current US$)', 223.6785642845238),
#  ('DT.INT.PCBK.PS.CD', 'PS, commercial banks (INT, current US$)', 222.74378504642854),
#  ('DT.AMT.PCBK.GG.CD', 'GG, commercial banks (AMT, current US$)', 207.6568557586666),
#  ('DT.AMT.OFFT.OPS.CD', 'OPS, official creditors (AMT, current US$)', 207.37523158571426),
#  ('DT.TDS.BLAT.OPS.CD', 'OPS, bilateral (TDS, current US$)', 199.5822228952381),
#  ('DT.AMT.BLAT.OPS.CD', 'OPS, bilateral (AMT, current US$)', 163.90316277142853),
#  ('DT.TDS.PRPG.CD', 'Debt service on external debt, private guaranteed by public sector (PPG) (TDS, current US$)', 163.29151960000002),
#  ('DT.INT.PRVT.PRVG.CD', 'PRVG, private creditors (INT, current US$)', 141.853531525),
#  ('DT.INT.PROP.PS.CD', 'PS, other private creditors (INT, current US$)', 139.70685042000002),
#  ('DT.INT.PROP.CD', 'PPG, other private creditors (INT, current US$)', 139.70685042000002),
#  ('DT.DIS.PROP.CD', 'PPG, other private creditors (DIS, current US$)', 129.46963590000001),
#  ('DT.AMT.PRPG.CD', 'Principal repayments on external debt, private guaranteed by public sector (PPG) (AMT, current US$)', 128.90961655555554),
#  ('DT.TDS.MLAT.OPS.CD', 'OPS, multilateral (TDS, current US$)', 125.80645733333328),
#  ('DT.AMT.PROP.PS.CD', 'PS, other private creditors (AMT, current US$)', 122.16793522285714),
#  ('DT.AMT.PROP.CD', 'PPG, other private creditors (AMT, current US$)', 122.16793522285714),
#  ('DT.TDS.PCBK.PRVG.CD', 'PRVG, commercial banks (TDS, current US$)', 111.2478567),
#  ('DT.INT.BLAT.CD', 'PPG, bilateral (INT, current US$)', 106.85465240327865),
#  ('DT.INT.BLAT.PS.CD', 'PS, bilateral (INT, current US$)', 106.75643800327865),
#  ('DT.AMT.MLAT.OPS.CD', 'OPS, multilateral (AMT, current US$)', 98.52250275555554),
#  ('DT.AMT.MLTC.PS.CD', 'PS, multilateral concessional (AMT, current US$)', 90.5538755017544),
#  ('DT.INT.BLAT.GG.CD', 'GG, bilateral (INT, current US$)', 86.99206704793387),
#  ('DT.TDS.BLTC.CD', 'PPG, bilateral concessional (TDS, current US$)', 83.62482788849555),
#  ('DT.AMT.PCBK.PRVG.CD', 'PRVG, commercial banks (AMT, current US$)', 71.98712865),
#  ('DT.TDS.PROP.GG.CD', 'GG, other private creditors (TDS, current US$)', 70.75913958275862),
#  ('DT.AMT.BLTC.CD', 'PPG, bilateral concessional (AMT, current US$)', 69.79775218672566),
#  ('DT.INT.PCBK.GG.CD', 'GG, commercial banks (INT, current US$)', 58.772648129333355),
#  ('DT.INT.DIMF.CD', 'IMF charges (INT, current US$)', 58.69119842772277),
#  ('DT.AMT.PROP.GG.CD', 'GG, other private creditors (AMT, current US$)', 54.35157805172415),
#  ('DT.INT.OFFT.OPS.CD', 'OPS, official creditors (INT, current US$)', 50.145541855952395),
#  ('DT.INT.PCBK.PRVG.CD', 'PRVG, commercial banks (INT, current US$)', 39.26072805),
#  ('DT.INT.BLAT.OPS.CD', 'OPS, bilateral (INT, current US$)', 35.67906011428569),
#  ('DT.INT.PRPG.CD', 'Interest payments on external debt, private guaranteed by public sector (PPG) (INT, current US$)', 34.38190304444444),
#  ('DT.INT.MLAT.OPS.CD', 'OPS, multilateral (INT, current US$)', 27.28395456527778),
#  ('DT.INT.MLTC.PS.CD', 'PS, multilateral concessional (INT, current US$)', 20.758670585964918),
#  ('DT.TDS.MLAT.PRVG.CD', 'PRVG, multilateral (TDS, current US$)', 18.84133436666667),
#  ('DT.TDS.OFFT.PRVG.CD', 'PRVG, official creditors (TDS, current US$)', 18.43709356),
#  ('DT.INT.PROP.GG.CD', 'GG, other private creditors (INT, current US$)', 16.40756153103448),
#  ('DT.AMT.MLAT.PRVG.CD', 'PRVG, multilateral (AMT, current US$)', 15.551503375),
#  ('DT.AMT.OFFT.PRVG.CD', 'PRVG, official creditors (AMT, current US$)', 15.006418313333333),
#  ('DT.INT.BLTC.CD', 'PPG, bilateral concessional (INT, current US$)', 13.827075701769914),
#  ('DT.TDS.BLAT.PRVG.CD', 'PRVG, bilateral (TDS, current US$)', 10.0920782),
#  ('DT.AMT.BLAT.PRVG.CD', 'PRVG, bilateral (AMT, current US$)', 7.695646840000001),
#  ('DT.INT.OFFT.PRVG.CD', 'PRVG, official creditors (INT, current US$)', 3.4306752466666666),
#  ('DT.TDS.MLTC.OPS.CD', 'OPS, multilateral concessional (TDS, current US$)', 3.4191681852941187),
#  ('DT.INT.MLAT.PRVG.CD', 'PRVG, multilateral (INT, current US$)', 3.289830991666667),
#  ('DT.AMT.MLTC.OPS.CD', 'OPS, multilateral concessional (AMT, current US$)', 2.688979479411765),
#  ('DT.INT.BLAT.PRVG.CD', 'PRVG, bilateral (INT, current US$)', 2.3964313600000002),
#  ('DT.INT.MLTC.OPS.CD', 'OPS, multilateral concessional (INT, current US$)', 0.7301887058823527)]

# %% [markdown]
# ## 7. The highest amount of principal repayments in million USD

# %%
# %%sql
#
# SELECT
#     country_name,
#     (AVG(debt_2024))/1000000 as average_debt,
#     indicator_name,
#     indicator_code
# FROM debt_stat
# WHERE debt_2024 IS NOT NULL
# GROUP BY country_name, indicator_name, indicator_code
# HAVING indicator_code = 'DT.AMT.DLXF.CD'
# ORDER BY average_debt DESC
# LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost/ids_database
# 5 rows affected.
# [('China', 136499.0, 'Principal repayments on external debt, long-term (AMT, current US$)', 'DT.AMT.DLXF.CD'),
#  ('Brazil', 63552.079416, 'Principal repayments on external debt, long-term (AMT, current US$)', 'DT.AMT.DLXF.CD'),
#  ('Mexico', 58749.554683, 'Principal repayments on external debt, long-term (AMT, current US$)', 'DT.AMT.DLXF.CD'),
#  ('Indonesia', 49998.418321, 'Principal repayments on external debt, long-term (AMT, current US$)', 'DT.AMT.DLXF.CD'),
#  ('India', 48670.851656, 'Principal repayments on external debt, long-term (AMT, current US$)', 'DT.AMT.DLXF.CD')]

# %% [markdown]
# ## 8. Some most common debt indicators across countries

# %%
# %%sql
#
# SELECT
#     indicator_name,
#     COUNT(indicator_code) as indicator_count
# FROM debt_stat
# WHERE debt_2024 IS NOT NULL
# GROUP BY indicator_code, indicator_name
# ORDER BY indicator_count DESC
# LIMIT 35;
# Out:
#  * postgresql://postgres:***@localhost/ids_database
# 35 rows affected.
# [('Principal repayments on external debt, long-term (AMT, current US$)', 122),
#  ('Multilateral debt service (TDS, current US$)', 122),
#  ('Interest payments on external debt, general government sector (PPG) (INT, current US$)', 122),
#  ('PS, bilateral (TDS, current US$)', 122),
#  ('Debt service on external debt, total (TDS, current US$)', 122),
#  ('PS, bilateral (AMT, current US$)', 122),
#  ('Interest payments on external debt, long-term (INT, current US$)', 122),
#  ('PS, official creditors (TDS, current US$)', 122),
#  ('PPG, bilateral (AMT, current US$)', 122),
#  ('GG, official creditors (INT, current US$)', 122),
#  ('PPG, multilateral (AMT, current US$)', 122),
#  ('PPG, official creditors (INT, current US$)', 122),
#  ('PS, official creditors (INT, current US$)', 122),
#  ('Debt service on external debt, public sector (PPG) (TDS, current US$)', 122),
#  ('GG, multilateral (INT, current US$)', 122),
#  ('Interest payments on external debt, public and publicly guaranteed (PPG) (INT, current US$)', 122),
#  ('PS, multilateral (TDS, current US$)', 122),
#  ('Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)', 122),
#  ('PPG, official creditors (AMT, current US$)', 122),
#  ('Principal repayments on external debt, general government sector (PPG) (AMT, current US$)', 122),
#  ('PPG, multilateral (INT, current US$)', 122),
#  ('PPG, bilateral (INT, current US$)', 122),
#  ('PS, bilateral (INT, current US$)', 122),
#  ('Principal repayments on external debt, public and publicly guaranteed (PPG) (AMT, current US$)', 122),
#  ('GG, official creditors (TDS, current US$)', 122),
#  ('PS, multilateral (AMT, current US$)', 122),
#  ('PS, multilateral (INT, current US$)', 122),
#  ('Debt service on external debt, long-term (TDS, current US$)', 122),
#  ('GG, multilateral (TDS, current US$)', 122),
#  ('Debt service on external debt, general government sector (PPG) (TDS, current US$)', 122),
#  ('PS, official creditors (AMT, current US$)', 122),
#  ('GG, multilateral (AMT, current US$)', 122),
#  ('GG, official creditors (AMT, current US$)', 122),
#  ('PPG, bilateral (TDS, current US$)', 122),
#  ('Interest payments on external debt, public sector (PPG) (INT, current US$)', 122)]

# %% [markdown]
# ## 9. Maximum amount of debt across the indicators along with the respective country names in billion USD

# %%
# %%sql
#
# SELECT
#     country_name,
#     indicator_name,
#     MAX(debt_2024)/1000000000 as maximum_debt
# FROM debt_stat
# WHERE debt_2024 IS NOT NULL
# GROUP BY country_name, indicator_name
# ORDER BY maximum_debt DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/ids_database
# 10 rows affected.
# [('China', 'Debt service on external debt, long-term (TDS, current US$)', 174.45),
#  ('China', 'Debt service on external debt, total (TDS, current US$)', 174.45),
#  ('China', 'Principal repayments on external debt, long-term (AMT, current US$)', 136.499),
#  ('China', 'Debt service on external debt, private nonguaranteed (PNG) (TDS, current US$)', 108.837),
#  ('China', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', 92.579375752),
#  ('Brazil', 'Debt service on external debt, total (TDS, current US$)', 85.265161411),
#  ('Brazil', 'Debt service on external debt, long-term (TDS, current US$)', 85.265161411),
#  ('Mexico', 'Debt service on external debt, long-term (TDS, current US$)', 81.956454973),
#  ('Mexico', 'Debt service on external debt, total (TDS, current US$)', 81.956454973),
#  ('India', 'Debt service on external debt, long-term (TDS, current US$)', 67.659423364)]

# %% [markdown]
# ## Conclusion
# ### Few deductions from analysis:
# <ul><b>120 countries</b> have taken loan from the world bank across <b>141 debt indicators</b> which amounts to <b>12.48 trillion US dollars</b>.</ul>
# <ul><b>China</b> has taken the most amount of loan (<b>1520 billion US dollars</b>) from the world bank and a  large chunk of its loan is under <b>debt service on external debt, long term(TDS, current US$)</b>.</ul>
# <ul>There are a total of <b>27</b> debt indicators in which all the countries listed in our dataset have taken debt. This indicates that all these countries are suffering from some common economic issues.</ul>
